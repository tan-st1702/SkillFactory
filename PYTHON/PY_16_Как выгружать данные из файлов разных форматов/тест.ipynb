# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQkMluczM8m55M15BQv81IFQyx71uFbv7ZwFoE1E_EXJUFPiGo2jyngWyHz8ubo9pRFpMWu_yTnb5GV/pub?output=csv')

display(df.head(10))
# Out:
#        Отметка времени    Ваше ФИО  Повестка дня определяется на месте  \
# 0  27.11.2023 12:52:30   Меркулова                                   1
# 1  27.11.2023 13:22:24     Смирнов                                   7
# 2  27.11.2023 13:23:43  Листовская                                   5
# 3  27.11.2023 13:52:36       Дзель                                   1
# 4  27.11.2023 14:11:14     Борисов                                   2
# 5  27.11.2023 14:23:47   Кузьминов                                   1
# 6  27.11.2023 15:17:43   Морозевич                                   2
# 7  27.11.2023 16:38:24    Козьяков                                   5
# 8  27.11.2023 17:01:13       Химич                                   2
# 9  27.11.2023 17:34:59   Запутряев                                   8
#
#    Цели совещания и вопросы для обсуждения неизвестны до начала совещания  \
# 0                                                  1
# 1                                                  7
# ...

# %%
df1 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQkMluczM8m55M15BQv81IFQyx71uFbv7ZwFoE1E_EXJUFPiGo2jyngWyHz8ubo9pRFpMWu_yTnb5GV/pub?gid=747601796&single=true&output=csv')

display(df1.head())
# Out:
#       Фамилия  Кол-во лет  Кол-во месяцев     Стаж
# 0   Меркулова          12               3  (3) > 8
# 1     Смирнов           0               7  (1) 0-1
# 2  Листовская           0               7  (1) 0-1
# 3       Дзель           0               9  (1) 0-1
# 4     Борисов           3              10  (2) 3-5

# %%
df = pd.merge(
    left=df,
    right=df1,
    left_on=['Ваше ФИО'],
    right_on=['Фамилия'],
    how='left'
    )

# %%
display(df)
# Out:
#         Отметка времени    Ваше ФИО  Повестка дня определяется на месте  \
# 0   27.11.2023 12:52:30   Меркулова                                   1
# 1   27.11.2023 13:22:24     Смирнов                                   7
# 2   27.11.2023 13:23:43  Листовская                                   5
# 3   27.11.2023 13:52:36       Дзель                                   1
# 4   27.11.2023 14:11:14     Борисов                                   2
# 5   27.11.2023 14:23:47   Кузьминов                                   1
# 6   27.11.2023 15:17:43   Морозевич                                   2
# 7   27.11.2023 16:38:24    Козьяков                                   5
# 8   27.11.2023 17:01:13       Химич                                   2
# 9   27.11.2023 17:34:59   Запутряев                                   8
# 10  27.11.2023 18:53:11    Шалунова                                   2
# 11  27.11.2023 20:25:37     Гришина                                   1
#
# ...

# %%
df['Общее кол-во месяцев'] = df['Кол-во лет']*12 + df['Кол-во месяцев']

# %%
df['На сколько бы Вы оценили общую эффективность совещаний, в которых принимаете участие?'].corr(df['Общее кол-во месяцев'])
# Out:
# 0.2522357492823015
